# %%
import pandas as pd

# %%
file_path = '/Users/gillian/Desktop/ASSIGNMENT3A/topSongsLyrics1950_2019 (1).csv'
songs_df = pd.read_csv(file_path)

# %%
songs_specific_year = songs_df[songs_df['year'] == 1988].sort_values(by='rank', ascending=True)
print(songs_specific_year.head(10))
# Out:
#      year  rank                            artist  \
# 380  1988     1                     Tracy Chapman
# 381  1988     2                         Metallica
# 382  1988     3                             N.W.A
# 383  1988     4            Rob Base & DJ E-Z Rock
# 384  1988     5                       Bobby Brown
# 385  1988     6                       Paula Abdul
# 386  1988     7                      Neneh Cherry
# 387  1988     8              Fine Young Cannibals
# 388  1988     9                      Bette Midler
# 389  1988    10  DJ Jazzy Jeff & The Fresh Prince
#
#                               song  \
# 380                       Fast Car
# 381                            One
# 382                Fuck Tha Police
# 383                   It Takes Two
# 384                 My Prerogative
# 385                    Straight Up
# 386                 Buffalo Stance
# 387            She Drives Me Crazy
# 388          Wind Beneath My Wings
# 389  Parents Just Don't Understand
#
#                                                 lyrics
# 380  You got a fast car|I want a ticket to anywhere...
# 381  I can't remember anything|Can't tell if this i...
# 382  Right about now, N.W.A court is in full effect...
# 383  Right about now, you're about to be possessed ...
# 384  Get busy!|Everybody's talkin' all this stuff a...
# 385  Lost in a dream|I don't know which way to go|(...
# 386  Will you stop this (Gigolo) **** scratching an...
# 387  I can't stop the way I feel|Things you do don'...
# 388  Oh, oh, oh, oh|It must have been cold there in...
# 389  You know parents are the same no matter time n...

# %%
songs_1980 = songs_df[songs_df['year'] == 1980].sort_values(by='rank', ascending=True)
print(songs_1980.head(20))
# Out:
#      year  rank           artist                         song  \
# 300  1980     1          Blondie                      Call Me
# 301  1980     2  Kool & The Gang                  Celebration
# 302  1980     3            Queen   Another One Bites the Dust
# 303  1980     4            AC/DC  You Shook Me All Night Long
# 304  1980     5     Joy Division      Love Will Tear Us Apart
# 305  1980     6             Devo                      Whip It
# 306  1980     7       Diana Ross                  Upside Down
# 307  1980     8       Irene Cara                         Fame
# 308  1980     9            AC/DC                Back In Black
# 309  1980    10      John Lennon    (Just Like) Starting Over
#
#                                                 lyrics
# 300  Color me your color, baby|Color me your car|Co...
# 301  Yahoo! (This is your celebration)|Yahoo! (This...
# 302  Ooh, let's go!|Steve walks warily down the str...
# 303  She was a fast machine, she kept her motor cle...
# 304  When routine bites hard and ambitions are low|...
# 305  Crack that whip|Give the past a slip|Step on a...
# 306  I said, Upside down, you're turning me|You're ...
# 307  Baby, look at me|And tell me what you see|You ...
# 308  Back in black, I hit the sack|I've been too lo...
# 309  Our life together is so precious together|We h...

# %%
artist_counts = songs_df['artist'].value_counts().head(20)

artist_counts.plot(kind='bar', figsize=(14, 7), color='skyblue', edgecolor='black', title='Top 20 Artists with the Most Songs in the Dataset')
# Out:
# <Axes: title={'center': 'Top 20 Artists with the Most Songs in the Dataset'}>
